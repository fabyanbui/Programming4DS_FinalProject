# %%
import numpy as np
import pandas as pd

# %%
sleep_df=pd.read_csv('Processed.csv')
sleep_df.head(50)
# Out:
#     Unnamed: 0                Start                  End  Sleep Quality (%)  \
# 0            0  2019-05-12 23:26:13  2019-05-13 06:11:03               60.0
# 1            1  2019-05-13 22:10:31  2019-05-14 06:10:42               73.0
# 2            2  2019-05-14 21:43:00  2019-05-15 06:10:41               86.0
# 3            3  2019-05-15 23:11:51  2019-05-16 06:13:59               77.0
# 4            4  2019-05-16 23:12:13  2019-05-17 06:20:32               78.0
# 5            5  2019-05-19 01:25:12  2019-05-19 08:43:11               72.0
# 6            6  2019-05-20 22:41:13  2019-05-21 06:22:58               73.0
# 7            7  2019-05-21 22:39:27  2019-05-22 06:00:55               78.0
# 8            8  2019-05-22 22:36:59  2019-05-23 06:03:59               84.0
# 9            9  2019-05-23 23:15:23  2019-05-24 06:33:47               88.0
# 10          10  2019-05-26 00:21:00  2019-05-26 08:19:28               71.0
# ...

# %%
sleep_df.info()
sleep_df['Weather temperature (°C)'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 921 entries, 0 to 920
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   921 non-null    int64
#  1   Start                        921 non-null    object
#  2   End                          921 non-null    object
#  3   Sleep Quality (%)            921 non-null    float64
#  4   Regularity (%)               921 non-null    float64
#  5   Steps                        921 non-null    int64
#  6   Alarm mode                   921 non-null    object
#  7   Movements per hour           921 non-null    float64
#  8   Time in bed (seconds)        921 non-null    float64
#  9   Time asleep (seconds)        921 non-null    float64
#  10  Time before sleep (seconds)  921 non-null    float64
#  11  Window start                 841 non-null    object
#  12  Window stop                  841 non-null    object
# ...
