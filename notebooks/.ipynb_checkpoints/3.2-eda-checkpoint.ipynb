# %% [markdown]
# <div style="text-align: center; background-color: #0A6EBD; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Final Project - Programming for Data Science
#     <div style="text-align: center; background-color: #0A6EBD; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#     @ FIT-HCMUS, VNU-HCM 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 3.2 - Exploratory data analysis
# </div>

# %%
import numpy as np
import pandas as pd
import datetime

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import geopandas as gpd
from matplotlib.colors import TwoSlopeNorm

# %%
processed_df = pd.read_csv('./../data/Processed.csv', index_col=0)

# %%
processed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_number          2747 non-null   int64
#  1   quantity_ordered      2747 non-null   int64
#  2   price_per_unit        2747 non-null   float64
#  3   orderline_number      2747 non-null   int64
#  4   sales                 2747 non-null   float64
#  5   order_date            2747 non-null   object
#  6   days_since_lastorder  2747 non-null   int64
#  7   status                2747 non-null   object
#  8   productline           2747 non-null   object
#  9   retail_price          2747 non-null   int64
#  10  product_code          2747 non-null   object
#  11  customer_name         2747 non-null   object
#  12  phone                 2747 non-null   object
#  13  address               2747 non-null   object
#  14  city                  2747 non-null   object
#  15  postalcode            2747 non-null   object
#  16  country               2747 non-null   object
#  17  last_name             2747 non-null   object
#  18  first_name            2747 non-null   object
#  19  deal_size             2747 non-null   object
# dtypes: float64(2), int64(5), object(13)
# memory usage: 450.7+ KB

# %%
processed_df["order_date"] = pd.to_datetime(processed_df["order_date"],dayfirst = True)
processed_df
# Out:
#       order_number  quantity_ordered  price_per_unit  orderline_number  \
# 0            10107                30           95.70                 2
# 1            10121                34           81.35                 5
# 2            10134                41           94.74                 2
# 3            10145                45           83.26                 6
# 4            10168                36           96.66                 1
# ...            ...               ...             ...               ...
# 2742         10350                20          112.22                15
# 2743         10373                29          137.19                 1
# 2744         10386                43          125.99                 4
# 2745         10397                34           62.24                 1
# 2746         10414                47           65.52                 9
#
#         sales order_date  days_since_lastorder    status  productline  \
# 0     2871.00 2018-02-24                   828   Shipped  Motorcycles
# 1     2765.90 2018-05-07                   757   Shipped  Motorcycles
# 2     3884.34 2018-07-01                   703   Shipped  Motorcycles
# 3     3746.70 2018-08-25                   649   Shipped  Motorcycles
# 4     3479.76 2018-10-28                   586   Shipped  Motorcycles
# ...       ...        ...                   ...       ...          ...
# 2742  2244.40 2019-12-02                  2924   Shipped        Ships
# 2743  3978.51 2020-01-31                  2865   Shipped        Ships
# 2744  5417.57 2020-03-01                  2836  Resolved        Ships
# 2745  2116.16 2020-03-28                  2810   Shipped        Ships
# 2746  3079.44 2020-05-06                  2772   On Hold        Ships
#
#       retail_price product_code            customer_name             phone  \
# 0               95     S10_1678        Land of Toys Inc.        2125557818
# 1               95     S10_1678       Reims Collectables        26.47.1555
# 2               95     S10_1678          Lyon Souveniers  +33 1 46 62 7555
# 3               95     S10_1678        Toys4GrownUps.com        6265557265
# 4               95     S10_1678     Technics Stores Inc.        6505556809
# ...            ...          ...                      ...               ...
# 2742            54     S72_3212    Euro Shopping Channel    (91) 555 94 44
# 2743            54     S72_3212  Oulu Toy Supplies, Inc.        981-443655
# 2744            54     S72_3212    Euro Shopping Channel    (91) 555 94 44
# 2745            54     S72_3212             Alpha Cognac        61.77.6555
# 2746            54     S72_3212        Gifts4AllAges.com        6175559555
#
#                             address        city postalcode  country  \
# 0           897 Long Airport Avenue         NYC      10022      USA
# 1                59 rue de l'Abbaye       Reims      51100   France
# 2     27 rue du Colonel Pierre Avia       Paris      75508   France
# 3                78934 Hillside Dr.    Pasadena      90003      USA
# 4                 9408 Furth Circle  Burlingame      94217      USA
# ...                             ...         ...        ...      ...
# 2742             C/ Moralzarzal, 86      Madrid      28034    Spain
# 2743                    Torikatu 38        Oulu      90110  Finland
# 2744             C/ Moralzarzal, 86      Madrid      28034    Spain
# 2745          1 rue Alsace-Lorraine    Toulouse      31000   France
# 2746             8616 Spinnaker Dr.      Boston      51003      USA
#
#       last_name first_name deal_size
# 0            Yu       Kwai     Small
# 1       Henriot       Paul     Small
# 2      Da Cunha     Daniel    Medium
# 3         Young      Julie    Medium
# 4        Hirano       Juri    Medium
# ...         ...        ...       ...
# 2742     Freyre      Diego     Small
# 2743  Koskitalo     Pirkko    Medium
# 2744     Freyre      Diego    Medium
# 2745     Roulet    Annette     Small
# 2746    Yoshido       Juri    Medium
#
# [2747 rows x 20 columns]

# %% [markdown]
# # Question: Thông tin phân loại khách hàng theo lợi ích mang lại cho doanh nghiệp

# %% [markdown]
# ## Step 1: Purpose

# %% [markdown]
# Qua tìm hiểu, ta có thể phân loại khách hàng theo lợi ích mang lại cho doanh nghiệp như sau:
# - Khách hàng trung thành: Đây là nhóm mang lại gần như trên 70% doanh thu cho doanh nghiệp. Nhóm khách hàng này cần vô cùng tin tưởng sử dụng dịch vụ của doanh nghiệp. cần có những chính sách đặc biệt để giữ chân nhóm khách hàng này.
# - ~~Khách hàng tiềm năng: Đây là nhóm đối tượng đã/đang sử dụng sản phẩm/dịch vụ của doanh nghiệp hoặc có thể chỉ là nhóm đối tượng chuẩn bị trở thành khách hàng của doanh nghiệp. Nhóm này sẽ mang lại lợi ích trong tương lai nếu có những chiến lược thúc đẩy doanh số phù hợp, cần những chính sách thu hút đặc biệt.~~
# - Khách hàng mang lại giá trị lợi ích nhỏ: Đây là nhóm mang lại doanh thu thấp cho doanh nghiệp. Nhóm này đa phần tập trung vào giá cả thấp và những loại hàng có giá trị nhỏ.
# - Khách hàng tiêu cực: Nhóm khách hàng này gồm những đối tượng mua hàng khó tính, có thể là một số khách hàng mua hàng một lần,...

# %% [markdown]
# ## Step 2: Analyzing

# %%
cleaned_df1 = processed_df.groupby(['phone','customer_name','first_name','last_name']).sum(numeric_only=True)['sales'].sort_values(ascending=False)
cleaned_df1.head(43).sum()/cleaned_df1.sum()
# Out:
# 0.6971644858260091

# %%
cleaned_df1 = cleaned_df1.reset_index().drop(columns='sales').head(43)
cleaned_df1
# Out:
#               phone                 customer_name first_name   last_name
# 0    (91) 555 94 44         Euro Shopping Channel      Diego      Freyre
# 1        4155551450  Mini Gifts Distributors Ltd.    Valarie      Nelson
# 2      03 9520 4555    Australian Collectors, Co.      Peter    Ferguson
# 3        2125557413            Muscle Machine Inc       Jeff       Young
# 4        40.67.8555             La Rochelle Gifts     Janine     Labrune
# 5      +65 221 7555       Dragon Souveniers, Ltd.       Eric   Natividad
# 6        2125557818             Land of Toys Inc.       Kwai          Yu
# 7        4085553659     The Sharp Gifts Warehouse        Sue       Frick
# 8    (171) 555-1555                AV Stores, Co.   Victoria    Ashworth
# 9      02 9936 8555       Anna's Decorations, Ltd       Anna      O'Hara
# 10  +61 2 9495 8555     Souveniers And Things Co.     Adrian      Huxley
# 11        6562-9555         Salzburg Collectables      Georg       Pipps
# 12       31 12 3555      Danish Wholesale Imports      Jytte    Petersen
# 13       78.32.5555        Saveley & Henriot, Co.       Mary     Saveley
# 14      0522-556555           L'ordine Souveniers   Maurizio      Moroni
# 15       035-640555                 Rovelli Gifts   Giovanni     Rovelli
# 16       26.47.1555            Reims Collectables       Paul     Henriot
# 17     0695-34 6555       Scandinavian Gift Ideas      Maria     Larsson
# 18       6035558647  Online Diecast Creations Co.    Valarie       Young
# 19       2155551555         Diecast Classics Inc.      Kyung          Yu
# 20       6505556809          Technics Stores Inc.       Juri      Hirano
# 21   (91) 555 22 82    Corrida Auto Replicas, Ltd     Mart¡n      Sommer
# 22  +81 3 3584 0555       Tokyo Collectables, Ltd      Akiko   Shimamura
# 23   (171) 555-2282         UK Collectables, Ltd.  Elizabeth       Devon
# 24      0897-034555               Vida Sport, Ltd    Michael        Holz
# 25       07-98 9555            Baane Mini Imports      Jonas  Bergulfsen
# 26     +65 224 1555              Handji Gifts& Co      Wendy   Victorino
# 27  +358 9 8045 555           Suominen Souveniers      Kalle    Suominen
# 28    +47 2267 3215                  Herkku Gifts     Veysel      Oeztan
# 29      90-224 8555          Toys of Finland, Co.      Matti   Karttunen
# 30       5085559555           Mini Creations Ltd.     Wing C         Tam
# 31       6265557265             Toys4GrownUps.com      Julie       Young
# 32       981-443655       Oulu Toy Supplies, Inc.     Pirkko   Koskitalo
# 33       6175558555          Marta's Replicas Co.      Marta   Hernandez
# 34       2035552570               Gift Depot Inc.      Julie        King
# 35       86 21 3555          Heintze Collectables      Palle       Ibsen
# 36     0221-5554327        Toms Spezialitten, Ltd  Henriette   Pfalzheim
# 37       5085552555              FunGiftIdeas.com    Violeta     Benitez
# 38   (1) 42.34.2555     La Corne D'abondance, Co.      Marie    Bertrand
# 39      011-4988555            Amica Models & Co.      Paolo     Accorti
# 40   +63 2 555 3587               Cruz & Sons Co.     Arnold        Cruz
# 41   (1) 47.55.6555              Auto Canal Petit  Dominique     Perrier
# 42   (171) 555-0297      Stylish Desk Decors, Co.        Ann       Brown

# %%
cleaned_df2 = processed_df.groupby(['phone','customer_name','first_name','last_name']).sum(numeric_only=True)['sales'].sort_values(ascending=False)
cleaned_df2 = cleaned_df2.reset_index().drop(columns='sales').iloc[43:]
cleaned_df2
# Out:
#                 phone                       customer_name  first_name  \
# 43         2125551500                     Vitachrome Inc.     Michael
# 44         7605558146        Collectable Mini Designs Co.     Valarie
# 45         9145554562                       Mini Classics       Steve
# 46  +49 69 66 90 2555                Blauer See Auto, Co.      Roland
# 47         2155559857        Motor Mint Distributors Inc.        Rosa
# 48         2015559350             Tekni Collectables Inc.     William
# 49         6175559555                   Gifts4AllAges.com        Juri
# 50         7025551838                  Signal Gift Stores         Sue
# 51         6175558555          Collectables For Less Inc.       Allen
# 52         88.60.1555                         Mini Caravy  Frederique
# 53         2035559545                    Super Scale Inc.      Leslie
# 54      +47 2212 1555           Norway Gifts By Mail, Co.         Jan
# 55   +33 1 46 62 7555                     Lyon Souveniers      Daniel
# 56      (93) 203 4555                  Enaco Distributors     Eduardo
# 57     (198) 555-8888                   giftsbymail.co.uk       Helen
# 58         2125558493                Classic Legends Inc.       Maria
# 59       0921-12 3555            Volvo Model Replicas, Co   Christina
# 60     (604) 555-3392      Canadian Gift Exchange Network       Yoshi
# 61       (02) 5554 67                          Petit Auto   Catherine
# 62         91.24.4555                Marseille Mini Autos    Laurence
# 63     (604) 555-4555   Royal Canadian Collectables, Ltd.   Elizabeth
# 64     (514) 555-8054        Quebec Home Shopping Network        Jean
# 65         6175552555                Diecast Collectables     Valarie
# 66         61.77.6555                        Alpha Cognac     Annette
# 67         20.16.1555            Daedalus Designs Imports     Martine
# 68   +81 06 6342 5555                Osaka Souveniers Co.        Mory
# 69         2155554695             Classic Gift Ideas, Inc   Francisca
# 70         30.59.8555                  Auto Assoc. & Cie.      Daniel
# 71     61-9-3844-6555        Australian Collectables, Ltd        Sean
# 72     61-7-3844-6555         Australian Gift Network, Co        Tony
# 73     +353 1862 1555             Clover Collections, Co.        Dean
# 74         2035554407                    Gift Ideas Corp.         Dan
# 75         6175557555            Online Mini Collectables      Miguel
# 76     (95) 555 82 82          Iberia Gift Imports, Corp.  Jose Pedro
# 77          7675-3555                     Mini Auto Werke      Roland
# 78         4155554312            Signal Collectibles Ltd.         Sue
# 79    +34 913 728 555                         CAF Imports       Jesus
# 80         3105553722         West Coast Collectables Co.       Steve
# 81         6175555555          Cambridge Collectables Co.       Kyung
# 82     (171) 555-7555      Double Decker Gift Stores, Ltd      Thomas
# 83  +49 89 61 08 9555  Bavarian Collectables Imports, Co.     Michael
# 84   (071) 23 67 2555                        Royale Belge     Pascale
# 85         2125551957                     Microscale Inc.         Kee
# 86         6175558428             Auto-Moto Classics Inc.      Leslie
# 87         40.32.2555                   Atelier graphique      Carine
# 88         3105552373                   Boards & Toys Co.      Leslie
#
#       last_name
# 43        Frick
# 44     Thompson
# 45        Frick
# 46       Keitel
# 47    Hernandez
# 48        Brown
# 49      Yoshido
# 50         King
# 51       Nelson
# 52      Citeaux
# 53       Murphy
# 54      Klaeboe
# 55     Da Cunha
# 56     Saavedra
# 57      Bennett
# 58    Hernandez
# 59     Berglund
# 60    Tannamuri
# 61        Dewey
# 62      Lebihan
# 63      Lincoln
# 64    Fresnisre
# 65       Franco
# 66       Roulet
# 67        Rance
# 68      Kentary
# 69    Cervantes
# 70       Tonini
# 71      Connery
# 72     Calaghan
# 73      Cassidy
# 74        Lewis
# 75      Barajas
# 76         Roel
# 77       Mendel
# 78       Taylor
# 79    Fernandez
# 80     Thompson
# 81        Tseng
# 82        Hardy
# 83  Donnermeyer
# 84     Cartrain
# 85          Kuo
# 86       Taylor
# 87      Schmitt
# 88        Young

# %%
cleaned_df3 = processed_df.groupby(['phone','customer_name',
                                    'first_name','last_name','order_number']).count().reset_index()[['phone','customer_name',
                                                                                                     'first_name','last_name','order_number']]
cleaned_df3 = cleaned_df3.groupby(['phone','customer_name','first_name','last_name']).count()
cleaned_df3 = cleaned_df3[cleaned_df3['order_number']<=2].reset_index()[['phone','customer_name','first_name','last_name']]
cleaned_df3
# Out:
#                 phone                       customer_name  first_name  \
# 0      (171) 555-7555      Double Decker Gift Stores, Ltd      Thomas
# 1      (198) 555-8888                   giftsbymail.co.uk       Helen
# 2      (604) 555-3392      Canadian Gift Exchange Network       Yoshi
# 3      (604) 555-4555   Royal Canadian Collectables, Ltd.   Elizabeth
# 4      (95) 555 82 82          Iberia Gift Imports, Corp.  Jose Pedro
# 5     +34 913 728 555                         CAF Imports       Jesus
# 6      +353 1862 1555             Clover Collections, Co.        Dean
# 7       +47 2212 1555           Norway Gifts By Mail, Co.         Jan
# 8   +49 89 61 08 9555  Bavarian Collectables Imports, Co.     Michael
# 9    +81 06 6342 5555                Osaka Souveniers Co.        Mory
# 10        011-4988555                  Amica Models & Co.       Paolo
# 11       0221-5554327              Toms Spezialitten, Ltd   Henriette
# 12        0897-034555                     Vida Sport, Ltd     Michael
# 13         20.16.1555            Daedalus Designs Imports     Martine
# 14         2035559545                    Super Scale Inc.      Leslie
# 15         2125551957                     Microscale Inc.         Kee
# 16         2155554695             Classic Gift Ideas, Inc   Francisca
# 17         30.59.8555                  Auto Assoc. & Cie.      Daniel
# 18         3105552373                   Boards & Toys Co.      Leslie
# 19         3105553722         West Coast Collectables Co.       Steve
# 20         4155554312            Signal Collectibles Ltd.         Sue
# 21         6175552555                Diecast Collectables     Valarie
# 22         6175555555          Cambridge Collectables Co.       Kyung
# 23         6175557555            Online Mini Collectables      Miguel
# 24         6175558555                Marta's Replicas Co.       Marta
# 25         7605558146        Collectable Mini Designs Co.     Valarie
# 26         86 21 3555                Heintze Collectables       Palle
# 27         9145554562                       Mini Classics       Steve
#
#       last_name
# 0         Hardy
# 1       Bennett
# 2     Tannamuri
# 3       Lincoln
# 4          Roel
# 5     Fernandez
# 6       Cassidy
# 7       Klaeboe
# 8   Donnermeyer
# 9       Kentary
# 10      Accorti
# 11    Pfalzheim
# 12         Holz
# 13        Rance
# 14       Murphy
# 15          Kuo
# 16    Cervantes
# 17       Tonini
# 18        Young
# 19     Thompson
# 20       Taylor
# 21       Franco
# 22        Tseng
# 23      Barajas
# 24    Hernandez
# 25     Thompson
# 26        Ibsen
# 27        Frick

# %% [markdown]
# ## Step 3: Visualization

# %%
# Plot 1
fig, ax = plt.subplots(figsize=(12, 5))
fig.suptitle('Khách hàng trung thành', fontsize=16, y=1.45)
ax.axis('off')
table = ax.table(cellText=cleaned_df1.values,
                 colLabels=cleaned_df1.columns,
                 cellLoc='center',
                 loc='center',
                 colColours=['#f3f3f3']*len(cleaned_df1.columns))
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)

# Plot 2
fig, ax = plt.subplots(figsize=(12, 5))
fig.suptitle('Khách hàng mang lại giá trị lợi ích nhỏ', fontsize=16, y=1.5)
ax.axis('off')
table = ax.table(cellText=cleaned_df2.values,
                 colLabels=cleaned_df2.columns,
                 cellLoc='center',
                 loc='center',
                 colColours=['#f3f3f3']*len(cleaned_df2.columns))
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)

# Plot 3
fig, ax = plt.subplots(figsize=(12, 5))
fig.suptitle('Khách hàng tiêu cực', fontsize=16, y=1.15)
ax.axis('off')
table = ax.table(cellText=cleaned_df3.values,
                 colLabels=cleaned_df3.columns,
                 cellLoc='center',
                 loc='center',
                 colColours=['#f3f3f3']*len(cleaned_df3.columns))
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)

# %% [markdown]
# ## Step 4: Give observations

# %% [markdown]
# Qua trực quan hóa, ta có thể biết được thông tin khách hàng thuộc những nhóm khách hàng khác nhau, từ đó có thể đưa ra chiến lược phù hợp để có thể tối đa hóa lợi nhuận cho công ty:
# - Đối với khách hàng trung thành:
#     - Cung cấp ưu đãi đặc biệt và giảm giá cho khách hàng thường xuyên.
#     - Tạo chương trình thưởng hoặc điểm tích lũy để khuyến khích sự trung thành.
#     - Tổ chức sự kiện đặc biệt hoặc trải nghiệm độc quyền cho khách hàng trung thành.
# - Đối với khách hàng mang lại giá trị lợi ích nhỏ:
#     - Tập trung vào việc cung cấp giải pháp hiệu quả và giá trị đối với họ.
#     - Tối ưu hóa trải nghiệm mua sắm và dịch vụ khách hàng để làm cho quá trình mua sắm trở nên thuận lợi.
#     - Gửi thông điệp về giá trị và lợi ích cụ thể của sản phẩm hoặc dịch vụ.
# - Đối với khách hàng tiêu cực:
#     - Lắng nghe và hiểu rõ nhu cầu cụ thể của họ để đáp ứng mọi yêu cầu.
#     - Cung cấp dịch vụ khách hàng tận tâm và chuyên nghiệp.
#     - Tạo ra các sản phẩm hoặc dịch vụ có thể tùy chỉnh để đáp ứng mong muốn đặc biệt của họ.

# %% [markdown]
# # Question: Doanh số bán hàng theo từng quốc gia

# %% [markdown]
# ## Step 1: Purpose

# %% [markdown]
# ## Step 2: Analyzing

# %%
cleaned_df = processed_df.groupby(['country']).sum(numeric_only=True)['sales']
cleaned_df = cleaned_df.rename(index={'USA': 'United States of America','UK': 'United Kingdom'})
cleaned_df
# Out:
# country
# Australia                    630623.10
# Austria                      202062.53
# Belgium                      108412.62
# Canada                       224078.56
# Denmark                      245637.15
# Finland                      329581.91
# France                      1110916.52
# Germany                      220472.09
# Ireland                       57756.43
# Italy                        374674.31
# Japan                        188167.81
# Norway                       307463.70
# Philippines                   94015.73
# Singapore                    288488.41
# Spain                       1215686.92
# Sweden                       210014.21
# Switzerland                  117713.56
# United Kingdom               478880.46
# United States of America    3355575.69
# Name: sales, dtype: float64

# %%
gdf = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf['sales'] = 0
for country in cleaned_df.index:
    gdf.loc[gdf.name == country, 'sales'] = cleaned_df[country]
### Missing Singapore
# Out:
# /tmp/ipykernel_663/3743934022.py:1: FutureWarning:
#
# The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.

# %% [markdown]
# ## Step 3: Visualization

# %%
cmap = 'tab20b'
cbar = plt.cm.ScalarMappable(cmap=cmap)
fig, ax = plt.subplots(1, 1, figsize=(20, 8))
gdf.plot(column='sales', cmap=cmap, legend=True, ax=ax, edgecolor="white", linewidths=0.3)
plt.title("World map sales")
plt.show()

# %% [markdown]
# ## Step 4: Give observations

# %% [markdown]
# Từ biểu đồ, ta có thể rút ra được các kết luận sau:
# - Doanh số bán hàng chủ yếu tập trung ở Mỹ và các nước châu Âu, cần tập trung nhiều hơn vào những thị trường ở những quốc gia này.
# - Một số các khu vực khác mà công ty cũng đang bắt đầu khai thác để tạo ra doanh thu nhiều hơn bao gồm Canada, Úc và một số nước châu Âu.
# - Tiếp tục khám phá tiềm năng doanh thu ở các quốc gia châu Á nhiều hơn để tăng doanh thu cho công ty.

# %% [markdown]
# # Question: Sự thay đổi doanh thu của từng dòng sản phẩm theo thời gian

# %% [markdown]
# ## Step 1: Purpose

# %% [markdown]
# ## Step 2: Analyzing

# %%
cleaned_df = processed_df.copy()
cleaned_df
# Out:
#       order_number  quantity_ordered  price_per_unit  orderline_number  \
# 0            10107                30           95.70                 2
# 1            10121                34           81.35                 5
# 2            10134                41           94.74                 2
# 3            10145                45           83.26                 6
# 4            10168                36           96.66                 1
# ...            ...               ...             ...               ...
# 2742         10350                20          112.22                15
# 2743         10373                29          137.19                 1
# 2744         10386                43          125.99                 4
# 2745         10397                34           62.24                 1
# 2746         10414                47           65.52                 9
#
#         sales order_date  days_since_lastorder    status  productline  \
# 0     2871.00 2018-02-24                   828   Shipped  Motorcycles
# 1     2765.90 2018-05-07                   757   Shipped  Motorcycles
# 2     3884.34 2018-07-01                   703   Shipped  Motorcycles
# 3     3746.70 2018-08-25                   649   Shipped  Motorcycles
# 4     3479.76 2018-10-28                   586   Shipped  Motorcycles
# ...       ...        ...                   ...       ...          ...
# 2742  2244.40 2019-12-02                  2924   Shipped        Ships
# 2743  3978.51 2020-01-31                  2865   Shipped        Ships
# 2744  5417.57 2020-03-01                  2836  Resolved        Ships
# 2745  2116.16 2020-03-28                  2810   Shipped        Ships
# 2746  3079.44 2020-05-06                  2772   On Hold        Ships
#
#       retail_price product_code            customer_name             phone  \
# 0               95     S10_1678        Land of Toys Inc.        2125557818
# 1               95     S10_1678       Reims Collectables        26.47.1555
# 2               95     S10_1678          Lyon Souveniers  +33 1 46 62 7555
# 3               95     S10_1678        Toys4GrownUps.com        6265557265
# 4               95     S10_1678     Technics Stores Inc.        6505556809
# ...            ...          ...                      ...               ...
# 2742            54     S72_3212    Euro Shopping Channel    (91) 555 94 44
# 2743            54     S72_3212  Oulu Toy Supplies, Inc.        981-443655
# 2744            54     S72_3212    Euro Shopping Channel    (91) 555 94 44
# 2745            54     S72_3212             Alpha Cognac        61.77.6555
# 2746            54     S72_3212        Gifts4AllAges.com        6175559555
#
#                             address        city postalcode  country  \
# 0           897 Long Airport Avenue         NYC      10022      USA
# 1                59 rue de l'Abbaye       Reims      51100   France
# 2     27 rue du Colonel Pierre Avia       Paris      75508   France
# 3                78934 Hillside Dr.    Pasadena      90003      USA
# 4                 9408 Furth Circle  Burlingame      94217      USA
# ...                             ...         ...        ...      ...
# 2742             C/ Moralzarzal, 86      Madrid      28034    Spain
# 2743                    Torikatu 38        Oulu      90110  Finland
# 2744             C/ Moralzarzal, 86      Madrid      28034    Spain
# 2745          1 rue Alsace-Lorraine    Toulouse      31000   France
# 2746             8616 Spinnaker Dr.      Boston      51003      USA
#
#       last_name first_name deal_size
# 0            Yu       Kwai     Small
# 1       Henriot       Paul     Small
# 2      Da Cunha     Daniel    Medium
# 3         Young      Julie    Medium
# 4        Hirano       Juri    Medium
# ...         ...        ...       ...
# 2742     Freyre      Diego     Small
# 2743  Koskitalo     Pirkko    Medium
# 2744     Freyre      Diego    Medium
# 2745     Roulet    Annette     Small
# 2746    Yoshido       Juri    Medium
#
# [2747 rows x 20 columns]

# %%
product_lines = cleaned_df.productline.unique()
product_lines
# Out:
# array(['Motorcycles', 'Classic Cars', 'Trucks and Buses', 'Vintage Cars',
#        'Planes', 'Ships', 'Trains'], dtype=object)

# %% [markdown]
# ## Step 3: Visualization

# %%
fig = px.line()
for i in range(0,len(product_lines)):
    temp = cleaned_df[cleaned_df['productline']==product_lines[i]][['order_date','sales']].groupby('order_date').sum().reset_index()
    fig.add_scatter(x=temp['order_date'], y=temp["sales"], name=product_lines[i])
fig.show()

# %% [markdown]
# ## Step 4: Give observations

# %% [markdown]
# # Question: Đánh giá chung về mức độ trung thành của khách hàng đối với dòng sản phẩm

# %% [markdown]
# ## Step 1: Purpose

# %% [markdown]
# ## Step 2: Analyzing

# %%
cleaned_df = processed_df.days_since_lastorder
cleaned_df
# Out:
# 0        828
# 1        757
# 2        703
# 3        649
# 4        586
#         ...
# 2742    2924
# 2743    2865
# 2744    2836
# 2745    2810
# 2746    2772
# Name: days_since_lastorder, Length: 2747, dtype: int64

# %% [markdown]
# ## Step 3: Visualization

# %%
plt.figure(1 , figsize = (15,8))
plt.hist(cleaned_df, bins=20)
plt.title('Đánh giá mức độ trung thành của khách hàng')
plt.show()

# %% [markdown]
# ## Step 4: Give observations

# %% [markdown]
# # Question: Liệu có trường hợp nào giá bán cao hơn giá niêm yết của sản phẩm hay không

# %% [markdown]
# ## Step 1: Purpose

# %% [markdown]
# ## Step 2: Analyzing

# %%
a = ((processed_df['price_per_unit'] / processed_df['retail_price']) > 1).value_counts()[True]

y = np.array([a, processed_df.shape[0]-a])
mylabels = ["Giá bán cao hơn giá niêm yết", ""]
myexplode = [0.1, 0]

plt.pie(y, labels = mylabels, explode = myexplode, startangle = 90, shadow = True)
plt.show()

# %% [markdown]
# ## Step 3: Visualization

# %% [markdown]
# ## Step 4: Give observations

# %% [markdown]
# # Question: Phân phối của kích thước đơn hàng biểu hiện như thế nào?

# %% [markdown]
# ## Step 1: Purpose

# %% [markdown]
# ## Step 2: Analyzing

# %%
plt.figure(1 , figsize = (15,8))
sns.boxplot(x = 'deal_size' , y = 'sales' , data = processed_df, legend=False)
plt.title('Sales Distribution in Deal Size')
plt.xlabel("Deal Size", fontsize=12)
plt.ylabel("Sales", fontsize=12)
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# ## Step 3: Visualization

# %% [markdown]
# ## Step 4: Give observations

# %% [markdown]
# # Question: Sự sai lệch của giá bán so với giá niêm yết

# %% [markdown]
# ## Step 1: Purpose

# %% [markdown]
# ## Step 2: Analyzing

# %%
cleaned_df = (abs(processed_df['price_per_unit'] - processed_df['retail_price'])/processed_df['retail_price'])

# %% [markdown]
# ## Step 3: Visualization

# %%
plt.figure(1 , figsize = (15,8))
cleaned_df.plot(kind='hist', bins=20, xlim=(0,2),
                title='Sai lệch của giá bán so với giá niêm yết')
plt.show()

# %% [markdown]
# ## Step 4: Give observations

# %% [markdown]
# # Question: Tương quan của những dữ liệu dạng số

# %% [markdown]
# ## Step 1: Purpose

# %% [markdown]
# ## Step 2: Analyzing

# %%
corr = processed_df[['quantity_ordered','price_per_unit','sales','days_since_lastorder','retail_price']].corr(method='pearson')
mask = np.triu(np.ones_like(corr))

# %% [markdown]
# ## Step 3: Visualization

# %%
fig = plt.subplots(figsize=(8, 5))
sns.heatmap(corr, annot=True,fmt='.2f',mask=mask, cbar=None, linewidth=0.5)
plt.show()

# %% [markdown]
# ## Step 4: Give observations

# %% [markdown]
# - Câu hỏi về tình hình kinh tế chung của công ty:
#     - So sánh tổng doanh thu trong 2 giai đoạn (1/6/2018-31/5/2019 và 1/6/2019-31/5/2020)
#     - So sánh doanh thu của từng dòng sản phẩm trong 2 giai đoạn (1/6/2018-31/5/2019 và 1/6/2019-31/5/2020)
#     - Doanh thu theo khu vực biểu thị lên bản đồ
# - Câu hỏi về giá niêm yết (meo)
# - Câu hỏi về DAYS_SINCE_LASTORDER => Phân phối
